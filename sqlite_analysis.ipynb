# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\gustavo elias\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\gustavo elias\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gustavo elias\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gustavo elias\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gustavo elias\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\gustavo elias\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 🔹 Importando bibliotecas
import sqlite3
import pandas as pd

# %%
# 🔹 Caminho do banco de dados SQLite
db_path = 'data/data.db'  # Certifique-se de colocar o caminho correto do banco

# %%
# 🔹 Conectar ao banco e listar tabelas existentes
conn = sqlite3.connect(db_path)
query = "SELECT name FROM sqlite_master WHERE type='table';"
tables = pd.read_sql(query, conn)
conn.close()
tables
# Out:
# Empty DataFrame
# Columns: [name]
# Index: []

# %%
# 🔹 Reabrindo conexão para inspecionar colunas da tabela
conn = sqlite3.connect(db_path)
query_columns = "PRAGMA table_info(dado_ventilador);"
columns_info = pd.read_sql(query_columns, conn)
conn.close()
columns_info
# Out:
# Empty DataFrame
# Columns: [cid, name, type, notnull, dflt_value, pk]
# Index: []

# %%
# 🔹 Carregar os primeiros 10 registros da tabela
conn = sqlite3.connect(db_path)
query_data = "SELECT * FROM dado_ventilador LIMIT 10;"
df = pd.read_sql(query_data, conn)
conn.close()
df
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\Gustavo Elias\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:2674, in SQLiteDatabase.execute(self, sql, params)
#    2673 try:
# -> 2674     cur.execute(sql, *args)
#    2675     return cur
#
# OperationalError: no such table: dado_ventilador
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[6], line 4
#       2 conn = sqlite3.connect(db_path)
#       3 query_data = "SELECT * FROM dado_ventilador LIMIT 10;"
# ----> 4 df = pd.read_sql(query_data, conn)
#       5 conn.close()
#       6 df
#
# File c:\Users\Gustavo Elias\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:706, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     704 with pandasSQL_builder(con) as pandas_sql:
#     705     if isinstance(pandas_sql, SQLiteDatabase):
# --> 706         return pandas_sql.read_query(
#     707             sql,
#     708             index_col=index_col,
#     709             params=params,
#     710             coerce_float=coerce_float,
#     711             parse_dates=parse_dates,
#     712             chunksize=chunksize,
#     713             dtype_backend=dtype_backend,
#     714             dtype=dtype,
#     715         )
#     717     try:
#     718         _is_table_name = pandas_sql.has_table(sql)
#
# File c:\Users\Gustavo Elias\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:2738, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2727 def read_query(
#    2728     self,
#    2729     sql,
#    (...)
#    2736     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2737 ) -> DataFrame | Iterator[DataFrame]:
# -> 2738     cursor = self.execute(sql, params)
#    2739     columns = [col_desc[0] for col_desc in cursor.description]
#    2741     if chunksize is not None:
#
# File c:\Users\Gustavo Elias\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:2686, in SQLiteDatabase.execute(self, sql, params)
#    2683     raise ex from inner_exc
#    2685 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2686 raise ex from exc
#
# DatabaseError: Execution failed on sql 'SELECT * FROM dado_ventilador LIMIT 10;': no such table: dado_ventilador
